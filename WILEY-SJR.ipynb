# %%
import pandas as pd

# %%
data=pd.read_csv('all.csv')
# Out:
# /Users/biyanxie/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (2,6,56,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   PT                                                 AU   BA   BE   GP  \
# 0  J                             Dewit, MA; Gillies, ER  NaN  NaN  NaN
# 1  J                                  Zhang, H; Zhu, QS  NaN  NaN  NaN
# 2  J  Yoshida, M; Roh, KH; Mandal, S; Bhaskar, S; Li...  NaN  NaN  NaN
# 3  J  Tsou, HK; Hsieh, PY; Chung, CJ; Tang, CH; Shyr...  NaN  NaN  NaN
# 4  J                            Doshi, N; Mitragotri, S  NaN  NaN  NaN
#
#                                                   AF   BF   CA  \
# 0           DeWit, Matthew A.; Gillies, Elizabeth R.  NaN  NaN
# 1                      Zhang, Huigang; Zhu, Qingshan  NaN  NaN
# 2  Yoshida, Mutsumi; Roh, Kyung-Ho; Mandal, Supar...  NaN  NaN
# 3  Tsou, Hsi-Kai; Hsieh, Ping-Yen; Chung, Chi-Jen...  NaN  NaN
# 4                   Doshi, Nishit; Mitragotri, Samir  NaN  NaN
#
#                                                   TI  \
# 0  A Cascade Biodegradable Polymer Based on Alter...
# ...

# %%
data2017=pd.read_csv('scimagojr 2017.csv', delimiter=';')
data2017.head(1)
# Out:
# /Users/biyanxie/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Rank  Sourceid                                 Title     Type  \
# 0     1     28773  CA - A Cancer Journal for Clinicians  journal
#
#                  Issn     SJR SJR Best Quartile  H index  Total Docs. (2017)  \
# 0  15424863, 00079235  61,786                Q1      137                  43
#
#    Total Docs. (3years)  Total Refs.  Total Cites (3years)  \
# 0                   130         3160                 16834
#
#    Citable Docs. (3years) Cites / Doc. (2years) Ref. / Doc.        Country  \
# 0                     109                198,90       73,49  United States
#
#          Publisher                      Categories
# 0  Wiley-Blackwell  Hematology (Q1); Oncology (Q1)

# %%
data2016=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2016.csv', delimiter=';')
data2015=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2015.csv', delimiter=';')
data2014=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2014.csv', delimiter=';')
data2013=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2013.csv', delimiter=';')
data2012=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2012.csv', delimiter=';')
data2011=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2011.csv', delimiter=';')
data2010=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2010.csv', delimiter=';')
data2009=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2009.csv', delimiter=';')
data2008=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2008.csv', delimiter=';')
data2007=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2007.csv', delimiter=';')
data2006=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2006.csv', delimiter=';')
data2005=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2005.csv', delimiter=';')
data2004=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2004.csv', delimiter=';')
data2003=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2003.csv', delimiter=';')
data2002=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2002.csv', delimiter=';')
data2001=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2001.csv', delimiter=';')
data2000=pd.read_csv('/Users/biyanxie/downloads/scimagojr 2000.csv', delimiter=';')
data1999=pd.read_csv('/Users/biyanxie/downloads/scimagojr 1999.csv', delimiter=';')
# Out:
# /Users/biyanxie/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def lower_dict(d):
    data_SJR_dict = d.set_index('Title')['SJR'].to_dict()
    new_dict = dict((k.lower(), v) for k, v in data_SJR_dict.items())
    return new_dict

# %%
data['SJR_2017']= data['SO'].str.lower().map(lower_dict(data2017))
data['SJR_2016']= data['SO'].str.lower().map(lower_dict(data2016))
data['SJR_2015']= data['SO'].str.lower().map(lower_dict(data2015))
data['SJR_2014']= data['SO'].str.lower().map(lower_dict(data2014))
data['SJR_2013']= data['SO'].str.lower().map(lower_dict(data2013))
data['SJR_2012']= data['SO'].str.lower().map(lower_dict(data2012))
data['SJR_2011']= data['SO'].str.lower().map(lower_dict(data2011))
data['SJR_2010']= data['SO'].str.lower().map(lower_dict(data2010))
data['SJR_2009']= data['SO'].str.lower().map(lower_dict(data2009))
data['SJR_2008']= data['SO'].str.lower().map(lower_dict(data2008))
data['SJR_2007']= data['SO'].str.lower().map(lower_dict(data2007))
data['SJR_2006']= data['SO'].str.lower().map(lower_dict(data2006))
data['SJR_2005']= data['SO'].str.lower().map(lower_dict(data2005))
data['SJR_2004']= data['SO'].str.lower().map(lower_dict(data2004))
data['SJR_2003']= data['SO'].str.lower().map(lower_dict(data2003))
data['SJR_2002']= data['SO'].str.lower().map(lower_dict(data2002))
data['SJR_2001']= data['SO'].str.lower().map(lower_dict(data2001))
data['SJR_2000']= data['SO'].str.lower().map(lower_dict(data2000))
data['SJR_1999']= data['SO'].str.lower().map(lower_dict(data1999))

# %%
data.to_csv('/Users/biyanxie/desktop/new_data.csv')
