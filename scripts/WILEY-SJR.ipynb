# %%
import pandas as pd

# %%
data=pd.read_csv('../data/raw_data/all.csv')
# Out:
# C:\Users\lin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2,6,56,65,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   PT                                                 AU   BA   BE   GP  \
# 0  J                             Dewit, MA; Gillies, ER  NaN  NaN  NaN
# 1  J                                  Zhang, H; Zhu, QS  NaN  NaN  NaN
# 2  J  Yoshida, M; Roh, KH; Mandal, S; Bhaskar, S; Li...  NaN  NaN  NaN
# 3  J  Tsou, HK; Hsieh, PY; Chung, CJ; Tang, CH; Shyr...  NaN  NaN  NaN
# 4  J                            Doshi, N; Mitragotri, S  NaN  NaN  NaN
#
#                                                   AF   BF   CA  \
# 0           DeWit, Matthew A.; Gillies, Elizabeth R.  NaN  NaN
# 1                      Zhang, Huigang; Zhu, Qingshan  NaN  NaN
# 2  Yoshida, Mutsumi; Roh, Kyung-Ho; Mandal, Supar...  NaN  NaN
# 3  Tsou, Hsi-Kai; Hsieh, Ping-Yen; Chung, Chi-Jen...  NaN  NaN
# 4                   Doshi, Nishit; Mitragotri, Samir  NaN  NaN
#
#                                                   TI  \
# 0  A Cascade Biodegradable Polymer Based on Alter...
# ...

# %%
data2017=pd.read_csv('../data/sjrdata/scimagojr 2017.csv', delimiter=';')
data2016=pd.read_csv('../data/sjrdata/scimagojr 2016.csv', delimiter=';')
data2015=pd.read_csv('../data/sjrdata/scimagojr 2015.csv', delimiter=';')
data2014=pd.read_csv('../data/sjrdata/scimagojr 2014.csv', delimiter=';')
data2013=pd.read_csv('../data/sjrdata/scimagojr 2013.csv', delimiter=';')
data2012=pd.read_csv('../data/sjrdata/scimagojr 2012.csv', delimiter=';')
data2011=pd.read_csv('../data/sjrdata/scimagojr 2011.csv', delimiter=';')
data2010=pd.read_csv('../data/sjrdata/scimagojr 2010.csv', delimiter=';')
data2009=pd.read_csv('../data/sjrdata/scimagojr 2009.csv', delimiter=';')
data2008=pd.read_csv('../data/sjrdata/scimagojr 2008.csv', delimiter=';')
data2007=pd.read_csv('../data/sjrdata/scimagojr 2007.csv', delimiter=';')
data2006=pd.read_csv('../data/sjrdata/scimagojr 2006.csv', delimiter=';')
data2005=pd.read_csv('../data/sjrdata/scimagojr 2005.csv', delimiter=';')
data2004=pd.read_csv('../data/sjrdata/scimagojr 2004.csv', delimiter=';')
data2003=pd.read_csv('../data/sjrdata/scimagojr 2003.csv', delimiter=';')
data2002=pd.read_csv('../data/sjrdata/scimagojr 2002.csv', delimiter=';')
data2001=pd.read_csv('../data/sjrdata/scimagojr 2001.csv', delimiter=';')
data2000=pd.read_csv('../data/sjrdata/scimagojr 2000.csv', delimiter=';')
data1999=pd.read_csv('../data/sjrdata/scimagojr 1999.csv', delimiter=';')
# Out:
# C:\Users\lin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def lower_dict(d):
    data_SJR_dict = d.set_index('Title')['SJR'].to_dict()
    new_dict = dict((k.lower(), v) for k, v in data_SJR_dict.items())
    return new_dict

# %%
data['SJR_2017']= data['SO'].str.lower().map(lower_dict(data2017))
data['SJR_2016']= data['SO'].str.lower().map(lower_dict(data2016))
data['SJR_2015']= data['SO'].str.lower().map(lower_dict(data2015))
data['SJR_2014']= data['SO'].str.lower().map(lower_dict(data2014))
data['SJR_2013']= data['SO'].str.lower().map(lower_dict(data2013))
data['SJR_2012']= data['SO'].str.lower().map(lower_dict(data2012))
data['SJR_2011']= data['SO'].str.lower().map(lower_dict(data2011))
data['SJR_2010']= data['SO'].str.lower().map(lower_dict(data2010))
data['SJR_2009']= data['SO'].str.lower().map(lower_dict(data2009))
data['SJR_2008']= data['SO'].str.lower().map(lower_dict(data2008))
data['SJR_2007']= data['SO'].str.lower().map(lower_dict(data2007))
data['SJR_2006']= data['SO'].str.lower().map(lower_dict(data2006))
data['SJR_2005']= data['SO'].str.lower().map(lower_dict(data2005))
data['SJR_2004']= data['SO'].str.lower().map(lower_dict(data2004))
data['SJR_2003']= data['SO'].str.lower().map(lower_dict(data2003))
data['SJR_2002']= data['SO'].str.lower().map(lower_dict(data2002))
data['SJR_2001']= data['SO'].str.lower().map(lower_dict(data2001))
data['SJR_2000']= data['SO'].str.lower().map(lower_dict(data2000))
data['SJR_1999']= data['SO'].str.lower().map(lower_dict(data1999))

# %%
data2017
# Out:
#         Rank     Sourceid                                              Title  \
# 0          1        28773               CA - A Cancer Journal for Clinicians
# 1          2        18991                            Nature Reviews Genetics
# 2          3        19434  MMWR. Recommendations and reports : Morbidity ...
# 3          4        58530  National vital statistics reports : from the C...
# 4          5        20315              Nature Reviews Molecular Cell Biology
# 5          6        29431                     Quarterly Journal of Economics
# 6          7        21318                          Nature Reviews Immunology
# 7          8  21100812243                           Nature Reviews Materials
# 8          9        18434                                               Cell
# 9         10  19700180594                Handbook of International Economics
# 10        11        12464                              Nature Reviews Cancer
# ...

# %%
data.to_csv('/Users/biyanxie/desktop/new_data.csv')
